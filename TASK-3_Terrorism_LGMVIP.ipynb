# %% [markdown]
#                                          INTERMEDIATE LEVEL TASK-3
#
#                           Exploratory Data Analysis on Dataset - Terrorism
#
# As a security/defense analyst, try to find out the hot zone of terrorism. You can choose any of the tool of your choice (Python/R/Tableau/PowerBI/Excel/SAP/SAS)
#
#
#                                    AUTHOR NAME- MADHAVI VIKAS INGALE.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
#Loading Or Reading The CSV File
Terrorism_Dataframe = pd.read_csv("C:\\users\\rohitingale\\Downloads\\globalterrorismdb_0718dist.csv",encoding='latin1',low_memory=False)

# %%
#Exploratory Data Analysis EDA on the dataset
Terrorism_Dataframe.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
# Display the last five rows of the data from dataset.
Terrorism_Dataframe.tail()
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country  country_txt  region  ... addnotes  \
# 181686      182      Somalia      11  ...      NaN
# 181687      200        Syria      10  ...      NaN
# 181688      160  Philippines       5  ...      NaN
# 181689       92        India       6  ...      NaN
# 181690      160  Philippines       5  ...      NaN
#
#                                                    scite1  \
# 181686  "Somalia: Al-Shabaab Militants Attack Army Che...
# 181687  "Putin's 'victory' in Syria has turned into a ...
# ...

# %%
#Renaming all Columns for understanding

Terrorism_Dataframe.rename(columns={'iyear':'Year','imonth':'Month','iday':"Day",'gname':'Group','country_txt':'Country','region_txt':'Region','provstate':'State','city':'City','latitude':'latitude',
    'longitude':'longitude','summary':'Summary','attacktype1_txt':'Attacktype','targtype1_txt':'Targettype','weaptype1_txt':'Weapon','nkill':'Kill',
     'nwound':'Wound'},inplace=True)

# %%
#Displays the Unique Value from the column City in the dataset.
Terrorism_Dataframe['City'].unique()
# Out:
# array(['Santo Domingo', 'Mexico city', 'Unknown', ..., 'Hungrum',
#        'Ceelka Geelow', 'Kubentog'], dtype=object)

# %%
# It shows the shape of the data variable in tuple format i.e. no. of rows and column.
Terrorism_Dataframe.shape
# Out:
# (181691, 135)

# %%
# Print the summary of the dataframe like no. of rows and detailed information about the columns.
Terrorism_Dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 146.9+ MB

# %%
# Shows the Statistical details of the column which has numerical values.
Terrorism_Dataframe.describe()
# Out:
#             eventid           Year          Month            Day  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %%
# Gives the count of categorical column with respect to each category.
pd.DataFrame(Terrorism_Dataframe.City).value_counts()
# Out:
# City
# Unknown         9775
# Baghdad         7589
# Karachi         2652
# Lima            2359
# Mosul           2265
#                 ...
# Jalle              1
# Jall al-Dieb       1
# Jalka Mela         1
# Jaljala            1
# zinarag            1
# Length: 36674, dtype: int64

# %%
# Gives the count of categorical column with respect to each category.
pd.DataFrame(Terrorism_Dataframe.Country).value_counts()
# Out:
# Country
# Iraq                   24636
# Pakistan               14368
# Afghanistan            12731
# India                  11960
# Colombia                8306
#                        ...
# Antigua and Barbuda        1
# New Hebrides               1
# St. Lucia                  1
# South Vietnam              1
# North Korea                1
# Length: 205, dtype: int64

# %%
# Checks whether the dataframe contains any null record or not and then gives the count of null records.
Terrorism_Dataframe.isna().sum()
# Out:
# eventid            0
# Year               0
# Month              0
# Day                0
# approxdate    172452
#                ...
# INT_LOG            0
# INT_IDEO           0
# INT_MISC           0
# INT_ANY            0
# related       156653
# Length: 135, dtype: int64

# %%
# Dropping the unnecessary columns
Terrorism_Dataframe.drop(['motive','Summary','latitude','longitude'],axis=1,inplace=True)

# %%
# It shows the shape of the data variable in tuple format i.e. no. of rows and column.
Terrorism_Dataframe.shape
# Out:
# (181691, 131)

# %%
# Shows the Statistical details of the column which has numerical values.
Terrorism_Dataframe.describe()
# Out:
#             eventid           Year          Month            Day  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region    specificity  \
# count  181691.000000  181691.000000  181691.000000  181685.000000
# mean        0.045346     131.968501       7.160938       1.451452
# std         0.208063     112.414535       2.933408       0.995430
# min         0.000000       4.000000       1.000000       1.000000
# ...

# %%
#Data Visualization
# Correlation Matrix
correlation = Terrorism_Dataframe.corr()
correlation
# Out:
#             eventid      Year     Month       Day  extended   country  \
# eventid    1.000000  0.999996  0.002706  0.018336  0.091761 -0.135039
# Year       0.999996  1.000000  0.000139  0.018254  0.091754 -0.135023
# Month      0.002706  0.000139  1.000000  0.005497 -0.000468 -0.006305
# Day        0.018336  0.018254  0.005497  1.000000 -0.004700  0.003468
# extended   0.091761  0.091754 -0.000468 -0.004700  1.000000 -0.020466
# ...             ...       ...       ...       ...       ...       ...
# nreleased -0.181612 -0.181556 -0.011535  0.001765 -0.192155 -0.044331
# INT_LOG   -0.143600 -0.143601 -0.002302 -0.001540  0.071768  0.069904
# INT_IDEO  -0.133252 -0.133253 -0.002034 -0.001621  0.075147  0.067564
# INT_MISC  -0.077852 -0.077847 -0.002554 -0.002027  0.027335  0.207281
# INT_ANY   -0.175605 -0.175596 -0.006336 -0.001199  0.080767  0.153118
#
#              region  specificity  vicinity     crit1  ...  ransomamt  \
# ...

# %%
#Visualize the Correlation matrix
sns.heatmap(correlation,annot=True)
# Out:
# <AxesSubplot:>

# %%
# Displays first 10 rows from value counts w.r.t country column
attack = Terrorism_Dataframe.Country.value_counts()[:10] 
attack
# Out:
# Iraq              24636
# Pakistan          14368
# Afghanistan       12731
# India             11960
# Colombia           8306
# Philippines        6908
# Peru               6096
# El Salvador        5320
# United Kingdom     5235
# Turkey             4292
# Name: Country, dtype: int64

# %%
year = Terrorism_Dataframe['Year'].unique()
years_count = Terrorism_Dataframe['Year'].value_counts(dropna = False).sort_index()
plt.figure(figsize = (16,8))
sns.barplot(x = year,y = years_count,palette = "Paired")
plt.xticks(rotation=90,fontsize=15)
plt.yticks(fontsize=15)
plt.xlabel('Attacking Year',fontsize=25)
plt.ylabel('Number of Attacks',fontsize=25)
plt.title('Attacks Analysis',fontsize=40)
plt.show()

# %%
df = Terrorism_Dataframe[['Year','Kill']].groupby(['Year']).sum()
fig, ax4 = plt.subplots(figsize=(20,15))
df.plot(kind='bar',alpha=0.7,ax=ax4)
plt.title("People Died Analysis",fontsize=25)
plt.ylabel("Number of killed people",fontsize=20)
plt.xlabel('Year',fontsize=20)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
# Out:
# (array([    0., 10000., 20000., 30000., 40000., 50000.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
pd.crosstab(Terrorism_Dataframe.Year, Terrorism_Dataframe.Region).plot(kind='area',stacked=False,figsize=(10,5))
plt.title('Terrorist Activities By Region In Each Year',fontsize=15)
plt.ylabel('Number of Terrorist Attacks',fontsize=15)
plt.xlabel("Years",fontsize=15)
plt.show()

# %%
plt.subplots(figsize=(10,5))
sns.barplot(x=Terrorism_Dataframe['Country'].value_counts()[:10].index,y=Terrorism_Dataframe['Country'].value_counts()[:10].values,palette="Set2")
plt.title('Counteries Affected By Attacks',fontsize=10)
plt.xlabel('Countries',fontsize=10)
plt.ylabel('Count',fontsize=10)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.show()

# %%
Terrorism_Dataframe[['Attacktype','Kill']].groupby(["Attacktype"],axis=0).sum().plot(kind='bar',figsize=(10,5),color="Red")
plt.xticks(rotation=30,fontsize=10)
plt.yticks(fontsize=10)
plt.title("Number of Killed vs Type of Attacks",fontsize=10)
plt.ylabel('Number of people killed',fontsize=10)
plt.xlabel('Type of Attacks',fontsize=10)
plt.show()

# %%
Terrorism_Dataframe['City'].value_counts().to_frame().sort_values('City',axis=0,ascending=False).head(10).plot(kind='bar',figsize=(10,5),color="Orange")
plt.xticks(rotation = 30,fontsize=10)
plt.yticks(fontsize=10)
plt.xlabel("City",fontsize=10)
plt.ylabel("Number of attack",fontsize=10)
plt.title("Top 10 most Affected city",fontsize=10)
plt.show()

# %%
Terrorism_Dataframe['Group'].value_counts().to_frame().drop('Unknown').head(10).plot(kind='bar',color='Green',figsize=(10,5))
plt.title("Top 10 Terrorist group Attack",fontsize=10)
plt.xlabel("Name of Terrorist Group",fontsize=10)
plt.ylabel("Number of Attacks",fontsize=10)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.show()

# %%
plt.subplots(figsize=(10,5))
sns.countplot(x=Terrorism_Dataframe["Targettype"],order=Terrorism_Dataframe['Targettype'].value_counts().index,palette="winter",edgecolor=sns.color_palette("winter"));
plt.xticks(rotation=90,fontsize=10)
plt.yticks(fontsize=10)
plt.xlabel("Type of Target",fontsize=10)
plt.ylabel("count",fontsize=10)
plt.title("Attack per Year",fontsize=10)
plt.show()

# %%
df=Terrorism_Dataframe[['Group','Country','Kill']]
df=df.groupby(['Group','Country'],axis=0).sum().sort_values('Kill',ascending=False).reset_index().head(10)
df
# Out:
#                                               Group      Country     Kill
# 0                                           Unknown         Iraq  38560.0
# 1       Islamic State of Iraq and the Levant (ISIL)         Iraq  31058.0
# 2                                           Taliban  Afghanistan  29269.0
# 3                                        Boko Haram      Nigeria  16917.0
# 4                                           Unknown     Pakistan  12023.0
# 5                                 Shining Path (SL)         Peru  11595.0
# 6           Liberation Tigers of Tamil Eelam (LTTE)    Sri Lanka  10928.0
# 7                                        Al-Shabaab      Somalia   8176.0
# 8  Farabundo Marti National Liberation Front (FMLN)  El Salvador   8019.0
# 9                                           Unknown  Afghanistan   7398.0

# %%
df=Terrorism_Dataframe[['Group','City','Kill']]
df=df.groupby(['Group','City'],axis=0).sum().sort_values('Kill',ascending=False).reset_index().head(10)
df
# Out:
#                                          Group           City     Kill
# 0                                      Unknown        Baghdad  14422.0
# 1                                      Unknown        Unknown   5766.0
# 2  Islamic State of Iraq and the Levant (ISIL)          Mosul   4760.0
# 3  Islamic State of Iraq and the Levant (ISIL)        Baghdad   3322.0
# 4                                   Al-Shabaab      Mogadishu   2845.0
# 5                                     Al-Qaida  New York City   2767.0
# 6                                      Unknown        Karachi   2390.0
# 7                                      Unknown          Mosul   2209.0
# 8                                   Boko Haram      Maiduguri   2171.0
# 9  Islamic State of Iraq and the Levant (ISIL)         Tikrit   1920.0
